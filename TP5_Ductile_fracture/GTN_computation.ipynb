# %% [markdown]
# ### Material definition

# %%
from dolfinx_materials.material import MFrontMaterial

general_properties = {
    "xyoung": 210e3,
    "xnu": 0.3,
    "R0": 507.0,
    "Rinf": 818.0,
    "b": 9.14,
    "q1": 1.5,
    "q2": 1.0,
    "q3": 2.25,
    "fc": 0.1,
    "fr": 0.25,
    "fn": 0.02,
    "en": 0.3,
    "sn": 0.1,
    "fini": 4e-3,
}

material = MFrontMaterial("src/libBehaviour.so", "GTN")
material.material_properties = {
    k: general_properties[k] for k in material.material_property_names
}
print("Material parameters:", material.material_property_names)
print("Gradients (inputs):", material.gradient_names)
print("Fluxes (outputs):", material.flux_names)
print("Internal state variables:", material.internal_state_variable_names)
# Out:
# Material parameters: ['xyoung', 'xnu', 'R0', 'Rinf', 'b', 'q1', 'q2', 'q3', 'fc', 'fr', 'fn', 'en', 'sn']
# Gradients (inputs): ['DeformationGradient']
# Fluxes (outputs): ['FirstPiolaKirchhoffStress']
# Internal state variables: ['ElasticStrain', 'Porosity', 'EquivalentPlasticStrain', 'Broken']

# %% [markdown]
# ## Problem implementation
#
# In this large-strain setting, the `QuadratureMapping` acts from the deformation gradient $\boldsymbol{F}=\boldsymbol{I}+\nabla\boldsymbol{u}$ to the first Piola-Kirchhoff stress $\boldsymbol{P}$. We will work in a Total Lagrangian formulation, writing the weak form of equilibrium on the reference configuration $\Omega_0$, thereby defining the nonlinear residual weak form as (no applied external forces):
# Find $\boldsymbol{u}\in V$ such that:
# $$
# \int_{\Omega_0} \boldsymbol{P}(\boldsymbol{F}(\boldsymbol{u})):\nabla \boldsymbol{v} \,\text{d}\Omega = 0 \quad \forall \boldsymbol{v}\in V
# $$
# Here the constitutive relation $\boldsymbol{P}(\boldsymbol{F})$ will be provided by the `QuadratureMap` loading a specific `MFront` file. Note that, in the above expression, we omitted internal state variables and their evolution equations

# %%
import numpy as np
import matplotlib.pyplot as plt
import ufl
from mpi4py import MPI
from dolfinx import fem
from dolfinx.cpp.nls.petsc import NewtonSolver
from dolfinx_materials.quadrature_map import QuadratureMap
from dolfinx_materials.solvers import NonlinearMaterialProblem
from dolfinx_materials.utils import axi_grad, nonsymmetric_tensor_to_vector

from mealor import DirichletBoundaryCondition
from mealor.utils import integrate, evaluate_on_points, save_to_file
from geometry import generate_NT
from load_stepping import LoadSteppingStrategy

## Define geometry and mesh (quadrangles)
R = 4.0            # notch radius
height = 23.0      # half-height of the specimen
Phi = 18.0         # maximum diameter
Phi_0 = 10.0       # minmum diameter
coarse_size = 2.0  # coarse mesh size
fine_size = 0.4    # fine mesh size
domain, cell_markers, facet_markers = generate_NT(height, Phi, Phi_0, R, coarse_size, fine_size)


## Setup function space, quadrature degree and integration measures
V = fem.VectorFunctionSpace(domain, ("CG", 1))
deg_quad = 1        # 1 Gauss points for linear quadrangles
ds = ufl.Measure(
    "ds",
    domain=domain,
    subdomain_data=facet_markers,
    metadata={"quadrature_degree": deg_quad},
)

## Boundary conditions
Uimp = fem.Constant(domain, 1.0)
dirichlet = DirichletBoundaryCondition(V)
dirichlet.add_bc_topological(facet_markers, 1, uy=0)
dirichlet.add_bc_topological(facet_markers, 2, ux=0, uy=Uimp)
dirichlet.add_bc_topological(facet_markers, 3, ux=0)


## Test, trial and unknown function
v = ufl.TestFunction(V)
du = ufl.TrialFunction(V)
u = fem.Function(V, name="Displacement")

# Dummy function used to compute force reaction
# fill with u=1 on imposed displacement boundary and use residual
v_reac = fem.Function(V)
fem.set_bc(v_reac.vector, dirichlet.bcs)

## Quadrature map object, needs to declare the "DeformationGradient" as a UFL expression of "u"
qmap = QuadratureMap(domain, deg_quad, material)
x = ufl.SpatialCoordinate(domain)
def F(u):
    return nonsymmetric_tensor_to_vector(ufl.Identity(3) + axi_grad(x[0], u))
qmap.register_gradient("DeformationGradient", F(u))


## Define non-linear residual weak form
# Note: in axisymmetric conditions, dx = dr*dz for the 2D mesh,
# hence, we use r = x[0] to write dOmega = r*dr*dz
PK1 = qmap.fluxes["FirstPiolaKirchhoffStress"]
Res = ufl.dot(PK1, ufl.derivative(F(u), u, v)) * x[0] * qmap.dx
Jac = qmap.derivative(Res, u, du)
problem = NonlinearMaterialProblem(qmap, Res, Jac, u, dirichlet.bcs)


# Create Newton solver
newton = NewtonSolver(MPI.COMM_WORLD)
newton.rtol = 1e-6
newton.atol = 1e-6
newton.convergence_criterion = "residual"
newton.max_it = 100


## Recover and initialize internal state variables
# Initialize initial porosity with fini
f = qmap.internal_state_variables["Porosity"]
fini = general_properties["fini"]
f.vector.array[:] = fini
qmap.update_initial_state("Porosity")
# Recover broken state variable
broken = qmap.internal_state_variables["Broken"]


## Define load stepping strategy 
# (heuristic to adapt time step to target a specific porosity increment `target_df`)
target_df = 1e-3  # target porosity increase
dU_max = 1e-2  # maximum displacement increment
dU_min = 1e-4  # minimum displacement increment
load_stepper = LoadSteppingStrategy(target_df, fini, dU_min, dU_max)


## Output file names
prefix = f"{material.name}_mesh_{fine_size}"
out_file = prefix + f"/results_R{R}.xdmf"


## Load-stepping loop
U_max = 1.5  # final displacement
dU = 1e-3  # first displacement increment
U = 0  # initial total displacement
i = 0
problem_stats = []
while U < U_max:
    i += 1
    U += dU
    Uimp.value = U
    dirichlet.update()

    # Solve nonlinear problem with Newton method
    converged, it = problem.solve(newton)

    # Compute number of broken points
    bp = broken.vector.array[:]
    num_broken = sum(broken.vector.array[:])
    print("Number of broken points", num_broken)

    # Compute maximum porosity for non-broken points
    f_max = max(f.vector.array[np.logical_not(bp)])

    # Update load step
    dU = load_stepper.new_step(dU, f_max)

    # Get internal state variables as DG-0 functions for output
    porosity = qmap.project_on("Porosity", ("DG", 0)) 
    p = qmap.project_on("EquivalentPlasticStrain", ("DG", 0))
    
    # Output to files
    rewrite = (i==1)
    save_to_file(out_file, u, t=U, rewrite=rewrite)
    save_to_file(out_file, porosity, t=U, rewrite=rewrite)
    save_to_file(out_file, p, t=U, rewrite=rewrite)

    # Evaluate fields at given points
    uv = evaluate_on_points(u, [Phi_0/2, 0, 0])
    pv = evaluate_on_points(p, [0.,0.,0.])
    DeltaPhi = -2*uv[0]
    
    
    # Nominal stress calculation
    S0 = np.pi * Phi_0**2 / 4
    # PK1_0 = qmap.project_on("FirstPiolaKirchhoffStress", ("DG", 0))
    Force = 2 * np.pi*integrate(ufl.action(Res, v_reac))


    print(
        f"Increment {i}\n  Strain: {U/height:.4f}   Stress: {Force/S0:.3f} MPa   max porosity: {f_max:.5f}    strain_increment: {dU:.5f}    porosity increment: {load_stepper.df_max:.5f}"
    )

    # Save to file
    problem_stats.append([U / height, f_max, pv, Force / S0, DeltaPhi, num_broken])
    results = np.asarray(problem_stats)
    np.savetxt(
        prefix + f"/results_R{R}.csv",
        results,
        delimiter=",",
        header="Strain, f_max, p, Sigma, DeltaPhi, num_broken",
    )
# Out:
#    WARNING: shrinks.length==shrinks_max=617
# Solution reached in 2 iterations.
# Number of broken points 0.0
# Increment 1
#   Strain: 0.0000   Stress: 21.023 MPa   max porosity: 0.00400    strain_increment: 0.00200    porosity increment: 0.00000
# Solution reached in 2 iterations.
# Number of broken points 0.0
# Increment 2
#   Strain: 0.0001   Stress: 63.060 MPa   max porosity: 0.00400    strain_increment: 0.00400    porosity increment: 0.00000
# Solution reached in 2 iterations.
# Number of broken points 0.0
# Increment 3
#   Strain: 0.0003   Stress: 147.100 MPa   max porosity: 0.00400    strain_increment: 0.00800    porosity increment: 0.00000
# Solution reached in 2 iterations.
# Number of broken points 0.0
# Increment 4
#   Strain: 0.0007   Stress: 315.039 MPa   max porosity: 0.00400    strain_increment: 0.01000    porosity increment: 0.00000
# Solution reached in 5 iterations.
# Number of broken points 0.0
# Increment 5
#   Strain: 0.0011   Stress: 517.524 MPa   max porosity: 0.00401    strain_increment: 0.01000    porosity increment: 0.00001
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 6
#   Strain: 0.0015   Stress: 670.160 MPa   max porosity: 0.00404    strain_increment: 0.01000    porosity increment: 0.00003
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 7
#   Strain: 0.0020   Stress: 710.239 MPa   max porosity: 0.00410    strain_increment: 0.01000    porosity increment: 0.00005
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 8
#   Strain: 0.0024   Stress: 730.053 MPa   max porosity: 0.00416    strain_increment: 0.01000    porosity increment: 0.00007
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 9
#   Strain: 0.0028   Stress: 744.410 MPa   max porosity: 0.00427    strain_increment: 0.01000    porosity increment: 0.00010
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 10
#   Strain: 0.0033   Stress: 756.126 MPa   max porosity: 0.00440    strain_increment: 0.01000    porosity increment: 0.00013
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 11
#   Strain: 0.0037   Stress: 766.252 MPa   max porosity: 0.00454    strain_increment: 0.01000    porosity increment: 0.00014
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 12
#   Strain: 0.0041   Stress: 775.263 MPa   max porosity: 0.00469    strain_increment: 0.01000    porosity increment: 0.00015
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 13
#   Strain: 0.0046   Stress: 783.426 MPa   max porosity: 0.00485    strain_increment: 0.01000    porosity increment: 0.00016
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 14
#   Strain: 0.0050   Stress: 790.850 MPa   max porosity: 0.00501    strain_increment: 0.01000    porosity increment: 0.00016
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 15
#   Strain: 0.0054   Stress: 797.627 MPa   max porosity: 0.00518    strain_increment: 0.01000    porosity increment: 0.00017
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 16
#   Strain: 0.0059   Stress: 803.861 MPa   max porosity: 0.00535    strain_increment: 0.01000    porosity increment: 0.00017
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 17
#   Strain: 0.0063   Stress: 809.609 MPa   max porosity: 0.00553    strain_increment: 0.01000    porosity increment: 0.00018
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 18
#   Strain: 0.0067   Stress: 814.882 MPa   max porosity: 0.00571    strain_increment: 0.01000    porosity increment: 0.00018
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 19
#   Strain: 0.0072   Stress: 819.711 MPa   max porosity: 0.00590    strain_increment: 0.01000    porosity increment: 0.00019
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 20
#   Strain: 0.0076   Stress: 824.137 MPa   max porosity: 0.00609    strain_increment: 0.01000    porosity increment: 0.00019
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 21
#   Strain: 0.0080   Stress: 828.185 MPa   max porosity: 0.00629    strain_increment: 0.01000    porosity increment: 0.00020
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 22
#   Strain: 0.0085   Stress: 831.858 MPa   max porosity: 0.00650    strain_increment: 0.01000    porosity increment: 0.00021
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 23
#   Strain: 0.0089   Stress: 835.195 MPa   max porosity: 0.00672    strain_increment: 0.01000    porosity increment: 0.00022
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 24
#   Strain: 0.0093   Stress: 838.215 MPa   max porosity: 0.00695    strain_increment: 0.01000    porosity increment: 0.00023
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 25
#   Strain: 0.0098   Stress: 840.929 MPa   max porosity: 0.00719    strain_increment: 0.01000    porosity increment: 0.00024
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 26
#   Strain: 0.0102   Stress: 843.354 MPa   max porosity: 0.00743    strain_increment: 0.01000    porosity increment: 0.00025
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 27
#   Strain: 0.0107   Stress: 845.496 MPa   max porosity: 0.00769    strain_increment: 0.01000    porosity increment: 0.00026
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 28
#   Strain: 0.0111   Stress: 847.366 MPa   max porosity: 0.00797    strain_increment: 0.01000    porosity increment: 0.00027
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 29
#   Strain: 0.0115   Stress: 848.976 MPa   max porosity: 0.00825    strain_increment: 0.01000    porosity increment: 0.00028
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 30
#   Strain: 0.0120   Stress: 850.332 MPa   max porosity: 0.00855    strain_increment: 0.01000    porosity increment: 0.00030
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 31
#   Strain: 0.0124   Stress: 851.449 MPa   max porosity: 0.00886    strain_increment: 0.01000    porosity increment: 0.00031
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 32
#   Strain: 0.0128   Stress: 852.332 MPa   max porosity: 0.00919    strain_increment: 0.01000    porosity increment: 0.00033
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 33
#   Strain: 0.0133   Stress: 852.991 MPa   max porosity: 0.00954    strain_increment: 0.01000    porosity increment: 0.00035
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 34
#   Strain: 0.0137   Stress: 853.433 MPa   max porosity: 0.00990    strain_increment: 0.01000    porosity increment: 0.00037
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 35
#   Strain: 0.0141   Stress: 853.661 MPa   max porosity: 0.01029    strain_increment: 0.01000    porosity increment: 0.00039
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 36
#   Strain: 0.0146   Stress: 853.685 MPa   max porosity: 0.01070    strain_increment: 0.01000    porosity increment: 0.00041
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 37
#   Strain: 0.0150   Stress: 853.506 MPa   max porosity: 0.01113    strain_increment: 0.01000    porosity increment: 0.00043
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 38
#   Strain: 0.0154   Stress: 853.128 MPa   max porosity: 0.01158    strain_increment: 0.01000    porosity increment: 0.00045
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 39
#   Strain: 0.0159   Stress: 852.558 MPa   max porosity: 0.01207    strain_increment: 0.01000    porosity increment: 0.00048
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 40
#   Strain: 0.0163   Stress: 851.801 MPa   max porosity: 0.01257    strain_increment: 0.01000    porosity increment: 0.00051
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 41
#   Strain: 0.0167   Stress: 850.861 MPa   max porosity: 0.01311    strain_increment: 0.01000    porosity increment: 0.00054
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 42
#   Strain: 0.0172   Stress: 849.742 MPa   max porosity: 0.01368    strain_increment: 0.01000    porosity increment: 0.00057
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 43
#   Strain: 0.0176   Stress: 848.445 MPa   max porosity: 0.01430    strain_increment: 0.01000    porosity increment: 0.00062
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 44
#   Strain: 0.0180   Stress: 846.973 MPa   max porosity: 0.01498    strain_increment: 0.01000    porosity increment: 0.00068
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 45
#   Strain: 0.0185   Stress: 845.329 MPa   max porosity: 0.01570    strain_increment: 0.01000    porosity increment: 0.00073
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 46
#   Strain: 0.0189   Stress: 843.515 MPa   max porosity: 0.01648    strain_increment: 0.01000    porosity increment: 0.00078
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 47
#   Strain: 0.0193   Stress: 841.533 MPa   max porosity: 0.01731    strain_increment: 0.01000    porosity increment: 0.00083
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 48
#   Strain: 0.0198   Stress: 839.384 MPa   max porosity: 0.01822    strain_increment: 0.01000    porosity increment: 0.00091
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 49
#   Strain: 0.0202   Stress: 837.070 MPa   max porosity: 0.01925    strain_increment: 0.01000    porosity increment: 0.00104
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 50
#   Strain: 0.0207   Stress: 834.593 MPa   max porosity: 0.02038    strain_increment: 0.01000    porosity increment: 0.00113
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 51
#   Strain: 0.0211   Stress: 831.952 MPa   max porosity: 0.02161    strain_increment: 0.00250    porosity increment: 0.00123
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 52
#   Strain: 0.0212   Stress: 831.268 MPa   max porosity: 0.02192    strain_increment: 0.00421    porosity increment: 0.00032
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 53
#   Strain: 0.0214   Stress: 830.094 MPa   max porosity: 0.02247    strain_increment: 0.00610    porosity increment: 0.00055
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 54
#   Strain: 0.0216   Stress: 828.339 MPa   max porosity: 0.02331    strain_increment: 0.00610    porosity increment: 0.00084
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 55
#   Strain: 0.0219   Stress: 826.524 MPa   max porosity: 0.02420    strain_increment: 0.00610    porosity increment: 0.00089
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 56
#   Strain: 0.0222   Stress: 824.648 MPa   max porosity: 0.02514    strain_increment: 0.00610    porosity increment: 0.00094
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 57
#   Strain: 0.0224   Stress: 822.712 MPa   max porosity: 0.02614    strain_increment: 0.00610    porosity increment: 0.00099
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 58
#   Strain: 0.0227   Stress: 820.715 MPa   max porosity: 0.02719    strain_increment: 0.00610    porosity increment: 0.00105
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 59
#   Strain: 0.0230   Stress: 818.657 MPa   max porosity: 0.02831    strain_increment: 0.00610    porosity increment: 0.00112
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 60
#   Strain: 0.0232   Stress: 816.537 MPa   max porosity: 0.02950    strain_increment: 0.00610    porosity increment: 0.00119
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 61
#   Strain: 0.0235   Stress: 814.356 MPa   max porosity: 0.03076    strain_increment: 0.00153    porosity increment: 0.00126
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 62
#   Strain: 0.0236   Stress: 813.802 MPa   max porosity: 0.03108    strain_increment: 0.00256    porosity increment: 0.00032
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 63
#   Strain: 0.0237   Stress: 812.864 MPa   max porosity: 0.03164    strain_increment: 0.00370    porosity increment: 0.00055
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 64
#   Strain: 0.0238   Stress: 811.486 MPa   max porosity: 0.03247    strain_increment: 0.00432    porosity increment: 0.00083
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 65
#   Strain: 0.0240   Stress: 809.848 MPa   max porosity: 0.03349    strain_increment: 0.00432    porosity increment: 0.00102
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 66
#   Strain: 0.0242   Stress: 808.177 MPa   max porosity: 0.03455    strain_increment: 0.00432    porosity increment: 0.00107
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 67
#   Strain: 0.0244   Stress: 806.474 MPa   max porosity: 0.03567    strain_increment: 0.00432    porosity increment: 0.00112
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 68
#   Strain: 0.0246   Stress: 804.738 MPa   max porosity: 0.03685    strain_increment: 0.00432    porosity increment: 0.00118
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 69
#   Strain: 0.0248   Stress: 802.968 MPa   max porosity: 0.03809    strain_increment: 0.00108    porosity increment: 0.00124
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 70
#   Strain: 0.0248   Stress: 802.521 MPa   max porosity: 0.03840    strain_increment: 0.00182    porosity increment: 0.00031
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 71
#   Strain: 0.0249   Stress: 801.763 MPa   max porosity: 0.03894    strain_increment: 0.00266    porosity increment: 0.00054
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 72
#   Strain: 0.0250   Stress: 800.643 MPa   max porosity: 0.03976    strain_increment: 0.00316    porosity increment: 0.00081
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 73
#   Strain: 0.0252   Stress: 799.297 MPa   max porosity: 0.04076    strain_increment: 0.00316    porosity increment: 0.00100
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 74
#   Strain: 0.0253   Stress: 797.932 MPa   max porosity: 0.04180    strain_increment: 0.00316    porosity increment: 0.00104
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 75
#   Strain: 0.0254   Stress: 796.548 MPa   max porosity: 0.04289    strain_increment: 0.00316    porosity increment: 0.00108
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 76
#   Strain: 0.0256   Stress: 795.144 MPa   max porosity: 0.04402    strain_increment: 0.00316    porosity increment: 0.00113
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 77
#   Strain: 0.0257   Stress: 793.719 MPa   max porosity: 0.04519    strain_increment: 0.00316    porosity increment: 0.00118
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 78
#   Strain: 0.0258   Stress: 792.273 MPa   max porosity: 0.04641    strain_increment: 0.00079    porosity increment: 0.00122
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 79
#   Strain: 0.0259   Stress: 791.909 MPa   max porosity: 0.04672    strain_increment: 0.00133    porosity increment: 0.00031
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 80
#   Strain: 0.0259   Stress: 791.290 MPa   max porosity: 0.04725    strain_increment: 0.00196    porosity increment: 0.00053
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 81
#   Strain: 0.0260   Stress: 790.374 MPa   max porosity: 0.04806    strain_increment: 0.00235    porosity increment: 0.00080
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 82
#   Strain: 0.0261   Stress: 789.262 MPa   max porosity: 0.04904    strain_increment: 0.00235    porosity increment: 0.00099
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 83
#   Strain: 0.0262   Stress: 788.137 MPa   max porosity: 0.05006    strain_increment: 0.00235    porosity increment: 0.00102
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 84
#   Strain: 0.0263   Stress: 786.999 MPa   max porosity: 0.05111    strain_increment: 0.00235    porosity increment: 0.00105
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 85
#   Strain: 0.0264   Stress: 785.847 MPa   max porosity: 0.05219    strain_increment: 0.00235    porosity increment: 0.00108
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 86
#   Strain: 0.0265   Stress: 784.681 MPa   max porosity: 0.05330    strain_increment: 0.00235    porosity increment: 0.00111
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 87
#   Strain: 0.0266   Stress: 783.500 MPa   max porosity: 0.05443    strain_increment: 0.00235    porosity increment: 0.00113
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 88
#   Strain: 0.0267   Stress: 782.303 MPa   max porosity: 0.05558    strain_increment: 0.00235    porosity increment: 0.00115
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 89
#   Strain: 0.0268   Stress: 781.089 MPa   max porosity: 0.05675    strain_increment: 0.00235    porosity increment: 0.00117
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 90
#   Strain: 0.0269   Stress: 779.857 MPa   max porosity: 0.05793    strain_increment: 0.00235    porosity increment: 0.00118
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 91
#   Strain: 0.0270   Stress: 778.605 MPa   max porosity: 0.05983    strain_increment: 0.00059    porosity increment: 0.00190
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 92
#   Strain: 0.0271   Stress: 778.290 MPa   max porosity: 0.06036    strain_increment: 0.00087    porosity increment: 0.00053
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 93
#   Strain: 0.0271   Stress: 777.822 MPa   max porosity: 0.06117    strain_increment: 0.00103    porosity increment: 0.00081
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 94
#   Strain: 0.0272   Stress: 777.263 MPa   max porosity: 0.06220    strain_increment: 0.00103    porosity increment: 0.00103
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 95
#   Strain: 0.0272   Stress: 776.699 MPa   max porosity: 0.06329    strain_increment: 0.00103    porosity increment: 0.00110
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 96
#   Strain: 0.0272   Stress: 776.130 MPa   max porosity: 0.06448    strain_increment: 0.00103    porosity increment: 0.00118
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 97
#   Strain: 0.0273   Stress: 775.555 MPa   max porosity: 0.06576    strain_increment: 0.00026    porosity increment: 0.00128
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 98
#   Strain: 0.0273   Stress: 775.411 MPa   max porosity: 0.06609    strain_increment: 0.00043    porosity increment: 0.00033
# Solution reached in 9 iterations.
# Number of broken points 0.0
# Increment 99
#   Strain: 0.0273   Stress: 775.169 MPa   max porosity: 0.06666    strain_increment: 0.00062    porosity increment: 0.00057
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 100
#   Strain: 0.0273   Stress: 774.820 MPa   max porosity: 0.06752    strain_increment: 0.00062    porosity increment: 0.00086
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 101
#   Strain: 0.0274   Stress: 774.469 MPa   max porosity: 0.06843    strain_increment: 0.00062    porosity increment: 0.00092
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 102
#   Strain: 0.0274   Stress: 774.116 MPa   max porosity: 0.06941    strain_increment: 0.00062    porosity increment: 0.00098
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 103
#   Strain: 0.0274   Stress: 773.760 MPa   max porosity: 0.07046    strain_increment: 0.00062    porosity increment: 0.00105
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 104
#   Strain: 0.0275   Stress: 773.400 MPa   max porosity: 0.07159    strain_increment: 0.00062    porosity increment: 0.00113
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 105
#   Strain: 0.0275   Stress: 773.037 MPa   max porosity: 0.07281    strain_increment: 0.00015    porosity increment: 0.00122
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 106
#   Strain: 0.0275   Stress: 772.946 MPa   max porosity: 0.07312    strain_increment: 0.00026    porosity increment: 0.00031
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 107
#   Strain: 0.0275   Stress: 772.792 MPa   max porosity: 0.07366    strain_increment: 0.00038    porosity increment: 0.00054
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 108
#   Strain: 0.0275   Stress: 772.565 MPa   max porosity: 0.07450    strain_increment: 0.00038    porosity increment: 0.00084
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 109
#   Strain: 0.0275   Stress: 772.337 MPa   max porosity: 0.07538    strain_increment: 0.00038    porosity increment: 0.00088
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 110
#   Strain: 0.0275   Stress: 772.107 MPa   max porosity: 0.07632    strain_increment: 0.00038    porosity increment: 0.00093
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 111
#   Strain: 0.0276   Stress: 771.876 MPa   max porosity: 0.07731    strain_increment: 0.00038    porosity increment: 0.00099
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 112
#   Strain: 0.0276   Stress: 771.641 MPa   max porosity: 0.07835    strain_increment: 0.00038    porosity increment: 0.00105
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 113
#   Strain: 0.0276   Stress: 771.405 MPa   max porosity: 0.07947    strain_increment: 0.00038    porosity increment: 0.00111
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 114
#   Strain: 0.0276   Stress: 771.165 MPa   max porosity: 0.08065    strain_increment: 0.00038    porosity increment: 0.00118
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 115
#   Strain: 0.0276   Stress: 770.923 MPa   max porosity: 0.08191    strain_increment: 0.00010    porosity increment: 0.00126
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 116
#   Strain: 0.0276   Stress: 770.859 MPa   max porosity: 0.08224    strain_increment: 0.00017    porosity increment: 0.00034
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 117
#   Strain: 0.0276   Stress: 770.751 MPa   max porosity: 0.08282    strain_increment: 0.00024    porosity increment: 0.00058
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 118
#   Strain: 0.0277   Stress: 770.597 MPa   max porosity: 0.08367    strain_increment: 0.00024    porosity increment: 0.00085
# Solution reached in 9 iterations.
# Number of broken points 0.0
# Increment 119
#   Strain: 0.0277   Stress: 770.441 MPa   max porosity: 0.08455    strain_increment: 0.00024    porosity increment: 0.00088
# Solution reached in 9 iterations.
# Number of broken points 0.0
# Increment 120
#   Strain: 0.0277   Stress: 770.283 MPa   max porosity: 0.08546    strain_increment: 0.00024    porosity increment: 0.00091
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 121
#   Strain: 0.0277   Stress: 770.124 MPa   max porosity: 0.08641    strain_increment: 0.00024    porosity increment: 0.00094
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 122
#   Strain: 0.0277   Stress: 769.963 MPa   max porosity: 0.08738    strain_increment: 0.00024    porosity increment: 0.00097
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 123
#   Strain: 0.0277   Stress: 769.801 MPa   max porosity: 0.08838    strain_increment: 0.00024    porosity increment: 0.00100
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 124
#   Strain: 0.0277   Stress: 769.637 MPa   max porosity: 0.08942    strain_increment: 0.00024    porosity increment: 0.00103
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 125
#   Strain: 0.0277   Stress: 769.471 MPa   max porosity: 0.09048    strain_increment: 0.00024    porosity increment: 0.00106
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 126
#   Strain: 0.0277   Stress: 769.303 MPa   max porosity: 0.09157    strain_increment: 0.00024    porosity increment: 0.00109
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 127
#   Strain: 0.0277   Stress: 769.134 MPa   max porosity: 0.09269    strain_increment: 0.00024    porosity increment: 0.00112
# Solution reached in 9 iterations.
# Number of broken points 0.0
# Increment 128
#   Strain: 0.0278   Stress: 768.962 MPa   max porosity: 0.09384    strain_increment: 0.00024    porosity increment: 0.00115
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 129
#   Strain: 0.0278   Stress: 768.788 MPa   max porosity: 0.09501    strain_increment: 0.00024    porosity increment: 0.00118
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 130
#   Strain: 0.0278   Stress: 768.612 MPa   max porosity: 0.09622    strain_increment: 0.00010    porosity increment: 0.00120
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 131
#   Strain: 0.0278   Stress: 768.537 MPa   max porosity: 0.09673    strain_increment: 0.00015    porosity increment: 0.00051
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 132
#   Strain: 0.0278   Stress: 768.425 MPa   max porosity: 0.09750    strain_increment: 0.00018    porosity increment: 0.00077
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 133
#   Strain: 0.0278   Stress: 768.286 MPa   max porosity: 0.09846    strain_increment: 0.00018    porosity increment: 0.00096
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 134
#   Strain: 0.0278   Stress: 768.146 MPa   max porosity: 0.09944    strain_increment: 0.00018    porosity increment: 0.00098
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 135
#   Strain: 0.0278   Stress: 767.993 MPa   max porosity: 0.10060    strain_increment: 0.00018    porosity increment: 0.00115
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 136
#   Strain: 0.0278   Stress: 767.824 MPa   max porosity: 0.10200    strain_increment: 0.00010    porosity increment: 0.00141
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 137
#   Strain: 0.0278   Stress: 767.731 MPa   max porosity: 0.10280    strain_increment: 0.00012    porosity increment: 0.00079
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 138
#   Strain: 0.0278   Stress: 767.616 MPa   max porosity: 0.10379    strain_increment: 0.00012    porosity increment: 0.00100
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 139
#   Strain: 0.0278   Stress: 767.499 MPa   max porosity: 0.10483    strain_increment: 0.00012    porosity increment: 0.00104
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 140
#   Strain: 0.0278   Stress: 767.367 MPa   max porosity: 0.10601    strain_increment: 0.00012    porosity increment: 0.00118
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 141
#   Strain: 0.0278   Stress: 767.233 MPa   max porosity: 0.10722    strain_increment: 0.00010    porosity increment: 0.00121
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 142
#   Strain: 0.0278   Stress: 767.121 MPa   max porosity: 0.10824    strain_increment: 0.00010    porosity increment: 0.00102
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 143
#   Strain: 0.0279   Stress: 767.008 MPa   max porosity: 0.10928    strain_increment: 0.00010    porosity increment: 0.00104
# Solution reached in 9 iterations.
# Number of broken points 0.0
# Increment 144
#   Strain: 0.0279   Stress: 766.893 MPa   max porosity: 0.11035    strain_increment: 0.00010    porosity increment: 0.00106
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 145
#   Strain: 0.0279   Stress: 766.777 MPa   max porosity: 0.11143    strain_increment: 0.00010    porosity increment: 0.00108
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 146
#   Strain: 0.0279   Stress: 766.645 MPa   max porosity: 0.11261    strain_increment: 0.00010    porosity increment: 0.00118
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 147
#   Strain: 0.0279   Stress: 766.501 MPa   max porosity: 0.11386    strain_increment: 0.00010    porosity increment: 0.00125
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 148
#   Strain: 0.0279   Stress: 766.355 MPa   max porosity: 0.11513    strain_increment: 0.00010    porosity increment: 0.00127
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 149
#   Strain: 0.0279   Stress: 766.207 MPa   max porosity: 0.11640    strain_increment: 0.00010    porosity increment: 0.00128
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 150
#   Strain: 0.0279   Stress: 766.058 MPa   max porosity: 0.11770    strain_increment: 0.00010    porosity increment: 0.00129
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 151
#   Strain: 0.0279   Stress: 765.908 MPa   max porosity: 0.11900    strain_increment: 0.00010    porosity increment: 0.00130
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 152
#   Strain: 0.0279   Stress: 765.756 MPa   max porosity: 0.12032    strain_increment: 0.00010    porosity increment: 0.00132
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 153
#   Strain: 0.0279   Stress: 765.602 MPa   max porosity: 0.12165    strain_increment: 0.00010    porosity increment: 0.00133
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 154
#   Strain: 0.0279   Stress: 765.447 MPa   max porosity: 0.12299    strain_increment: 0.00010    porosity increment: 0.00134
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 155
#   Strain: 0.0279   Stress: 765.289 MPa   max porosity: 0.12435    strain_increment: 0.00010    porosity increment: 0.00136
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 156
#   Strain: 0.0279   Stress: 765.129 MPa   max porosity: 0.12572    strain_increment: 0.00010    porosity increment: 0.00137
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 157
#   Strain: 0.0279   Stress: 764.939 MPa   max porosity: 0.12721    strain_increment: 0.00010    porosity increment: 0.00149
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 158
#   Strain: 0.0279   Stress: 764.731 MPa   max porosity: 0.12876    strain_increment: 0.00010    porosity increment: 0.00156
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 159
#   Strain: 0.0279   Stress: 764.519 MPa   max porosity: 0.13034    strain_increment: 0.00010    porosity increment: 0.00157
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 160
#   Strain: 0.0279   Stress: 764.302 MPa   max porosity: 0.13192    strain_increment: 0.00010    porosity increment: 0.00159
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 161
#   Strain: 0.0279   Stress: 764.081 MPa   max porosity: 0.13352    strain_increment: 0.00010    porosity increment: 0.00160
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 162
#   Strain: 0.0279   Stress: 763.856 MPa   max porosity: 0.13514    strain_increment: 0.00010    porosity increment: 0.00161
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 163
#   Strain: 0.0279   Stress: 763.627 MPa   max porosity: 0.13676    strain_increment: 0.00010    porosity increment: 0.00162
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 164
#   Strain: 0.0279   Stress: 763.394 MPa   max porosity: 0.13839    strain_increment: 0.00010    porosity increment: 0.00163
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 165
#   Strain: 0.0279   Stress: 763.159 MPa   max porosity: 0.14002    strain_increment: 0.00010    porosity increment: 0.00163
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 166
#   Strain: 0.0280   Stress: 762.921 MPa   max porosity: 0.14165    strain_increment: 0.00010    porosity increment: 0.00163
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 167
#   Strain: 0.0280   Stress: 762.682 MPa   max porosity: 0.14328    strain_increment: 0.00010    porosity increment: 0.00163
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 168
#   Strain: 0.0280   Stress: 762.441 MPa   max porosity: 0.14491    strain_increment: 0.00010    porosity increment: 0.00163
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 169
#   Strain: 0.0280   Stress: 762.198 MPa   max porosity: 0.14654    strain_increment: 0.00010    porosity increment: 0.00163
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 170
#   Strain: 0.0280   Stress: 761.955 MPa   max porosity: 0.14816    strain_increment: 0.00010    porosity increment: 0.00163
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 171
#   Strain: 0.0280   Stress: 761.710 MPa   max porosity: 0.14978    strain_increment: 0.00010    porosity increment: 0.00162
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 172
#   Strain: 0.0280   Stress: 761.464 MPa   max porosity: 0.15140    strain_increment: 0.00010    porosity increment: 0.00162
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 173
#   Strain: 0.0280   Stress: 761.217 MPa   max porosity: 0.15302    strain_increment: 0.00010    porosity increment: 0.00162
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 174
#   Strain: 0.0280   Stress: 760.967 MPa   max porosity: 0.15465    strain_increment: 0.00010    porosity increment: 0.00162
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 175
#   Strain: 0.0280   Stress: 760.717 MPa   max porosity: 0.15627    strain_increment: 0.00010    porosity increment: 0.00162
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 176
#   Strain: 0.0280   Stress: 760.466 MPa   max porosity: 0.15789    strain_increment: 0.00010    porosity increment: 0.00162
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 177
#   Strain: 0.0280   Stress: 760.214 MPa   max porosity: 0.15950    strain_increment: 0.00010    porosity increment: 0.00162
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 178
#   Strain: 0.0280   Stress: 759.962 MPa   max porosity: 0.16111    strain_increment: 0.00010    porosity increment: 0.00161
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 179
#   Strain: 0.0280   Stress: 759.709 MPa   max porosity: 0.16273    strain_increment: 0.00010    porosity increment: 0.00161
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 180
#   Strain: 0.0280   Stress: 759.448 MPa   max porosity: 0.16436    strain_increment: 0.00010    porosity increment: 0.00163
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 181
#   Strain: 0.0280   Stress: 759.148 MPa   max porosity: 0.16609    strain_increment: 0.00010    porosity increment: 0.00174
# Solution reached in 8 iterations.
# Number of broken points 0.0
# Increment 182
#   Strain: 0.0280   Stress: 758.848 MPa   max porosity: 0.16782    strain_increment: 0.00010    porosity increment: 0.00173
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 183
#   Strain: 0.0280   Stress: 758.549 MPa   max porosity: 0.16955    strain_increment: 0.00010    porosity increment: 0.00172
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 184
#   Strain: 0.0280   Stress: 758.250 MPa   max porosity: 0.17126    strain_increment: 0.00010    porosity increment: 0.00171
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 185
#   Strain: 0.0280   Stress: 757.953 MPa   max porosity: 0.17297    strain_increment: 0.00010    porosity increment: 0.00171
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 186
#   Strain: 0.0280   Stress: 757.656 MPa   max porosity: 0.17467    strain_increment: 0.00010    porosity increment: 0.00170
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 187
#   Strain: 0.0280   Stress: 757.359 MPa   max porosity: 0.17637    strain_increment: 0.00010    porosity increment: 0.00170
# Solution reached in 5 iterations.
# Number of broken points 0.0
# Increment 188
#   Strain: 0.0280   Stress: 757.063 MPa   max porosity: 0.17806    strain_increment: 0.00010    porosity increment: 0.00169
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 189
#   Strain: 0.0281   Stress: 756.767 MPa   max porosity: 0.17974    strain_increment: 0.00010    porosity increment: 0.00169
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 190
#   Strain: 0.0281   Stress: 756.382 MPa   max porosity: 0.18161    strain_increment: 0.00010    porosity increment: 0.00187
# Solution reached in 7 iterations.
# Number of broken points 0.0
# Increment 191
#   Strain: 0.0281   Stress: 755.976 MPa   max porosity: 0.18351    strain_increment: 0.00010    porosity increment: 0.00190
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 192
#   Strain: 0.0281   Stress: 755.570 MPa   max porosity: 0.18541    strain_increment: 0.00010    porosity increment: 0.00190
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 193
#   Strain: 0.0281   Stress: 755.163 MPa   max porosity: 0.18730    strain_increment: 0.00010    porosity increment: 0.00189
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 194
#   Strain: 0.0281   Stress: 754.602 MPa   max porosity: 0.18948    strain_increment: 0.00010    porosity increment: 0.00217
# Solution reached in 5 iterations.
# Number of broken points 0.0
# Increment 195
#   Strain: 0.0281   Stress: 753.860 MPa   max porosity: 0.19202    strain_increment: 0.00010    porosity increment: 0.00254
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 196
#   Strain: 0.0281   Stress: 753.082 MPa   max porosity: 0.19464    strain_increment: 0.00010    porosity increment: 0.00262
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 197
#   Strain: 0.0281   Stress: 752.337 MPa   max porosity: 0.19717    strain_increment: 0.00010    porosity increment: 0.00253
# Solution reached in 5 iterations.
# Number of broken points 0.0
# Increment 198
#   Strain: 0.0281   Stress: 751.623 MPa   max porosity: 0.19963    strain_increment: 0.00010    porosity increment: 0.00246
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 199
#   Strain: 0.0281   Stress: 750.934 MPa   max porosity: 0.20203    strain_increment: 0.00010    porosity increment: 0.00240
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 200
#   Strain: 0.0281   Stress: 750.270 MPa   max porosity: 0.20437    strain_increment: 0.00010    porosity increment: 0.00235
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 201
#   Strain: 0.0281   Stress: 749.625 MPa   max porosity: 0.20668    strain_increment: 0.00010    porosity increment: 0.00230
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 202
#   Strain: 0.0281   Stress: 748.999 MPa   max porosity: 0.20894    strain_increment: 0.00010    porosity increment: 0.00226
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 203
#   Strain: 0.0281   Stress: 748.390 MPa   max porosity: 0.21117    strain_increment: 0.00010    porosity increment: 0.00223
# Solution reached in 5 iterations.
# Number of broken points 0.0
# Increment 204
#   Strain: 0.0281   Stress: 747.795 MPa   max porosity: 0.21338    strain_increment: 0.00010    porosity increment: 0.00220
# Solution reached in 5 iterations.
# Number of broken points 0.0
# Increment 205
#   Strain: 0.0281   Stress: 747.143 MPa   max porosity: 0.21568    strain_increment: 0.00010    porosity increment: 0.00230
# Solution reached in 5 iterations.
# Number of broken points 0.0
# Increment 206
#   Strain: 0.0281   Stress: 746.426 MPa   max porosity: 0.21809    strain_increment: 0.00010    porosity increment: 0.00242
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 207
#   Strain: 0.0281   Stress: 745.731 MPa   max porosity: 0.22048    strain_increment: 0.00010    porosity increment: 0.00238
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 208
#   Strain: 0.0281   Stress: 745.055 MPa   max porosity: 0.22283    strain_increment: 0.00010    porosity increment: 0.00236
# Solution reached in 5 iterations.
# Number of broken points 0.0
# Increment 209
#   Strain: 0.0281   Stress: 744.398 MPa   max porosity: 0.22517    strain_increment: 0.00010    porosity increment: 0.00233
# Solution reached in 5 iterations.
# Number of broken points 0.0
# Increment 210
#   Strain: 0.0281   Stress: 743.757 MPa   max porosity: 0.22749    strain_increment: 0.00010    porosity increment: 0.00232
# Solution reached in 5 iterations.
# Number of broken points 0.0
# Increment 211
#   Strain: 0.0281   Stress: 743.131 MPa   max porosity: 0.22979    strain_increment: 0.00010    porosity increment: 0.00231
# Solution reached in 5 iterations.
# Number of broken points 0.0
# Increment 212
#   Strain: 0.0282   Stress: 742.519 MPa   max porosity: 0.23209    strain_increment: 0.00010    porosity increment: 0.00230
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 213
#   Strain: 0.0282   Stress: 741.919 MPa   max porosity: 0.23438    strain_increment: 0.00010    porosity increment: 0.00229
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 214
#   Strain: 0.0282   Stress: 741.331 MPa   max porosity: 0.23667    strain_increment: 0.00010    porosity increment: 0.00229
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 215
#   Strain: 0.0282   Stress: 740.753 MPa   max porosity: 0.23896    strain_increment: 0.00010    porosity increment: 0.00229
# Solution reached in 5 iterations.
# Number of broken points 0.0
# Increment 216
#   Strain: 0.0282   Stress: 740.185 MPa   max porosity: 0.24126    strain_increment: 0.00010    porosity increment: 0.00230
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 217
#   Strain: 0.0282   Stress: 739.626 MPa   max porosity: 0.24357    strain_increment: 0.00010    porosity increment: 0.00231
# Solution reached in 6 iterations.
# Number of broken points 0.0
# Increment 218
#   Strain: 0.0282   Stress: 739.075 MPa   max porosity: 0.24588    strain_increment: 0.00010    porosity increment: 0.00232
# Solution reached in 5 iterations.
# Number of broken points 1.0
# Increment 219
#   Strain: 0.0282   Stress: 738.492 MPa   max porosity: 0.18889    strain_increment: 0.00010    porosity increment: 0.05700
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 220
#   Strain: 0.0282   Stress: 737.891 MPa   max porosity: 0.18985    strain_increment: 0.00010    porosity increment: 0.00096
# Solution reached in 5 iterations.
# Number of broken points 1.0
# Increment 221
#   Strain: 0.0282   Stress: 737.298 MPa   max porosity: 0.19079    strain_increment: 0.00010    porosity increment: 0.00095
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 222
#   Strain: 0.0282   Stress: 736.715 MPa   max porosity: 0.19173    strain_increment: 0.00010    porosity increment: 0.00094
# Solution reached in 5 iterations.
# Number of broken points 1.0
# Increment 223
#   Strain: 0.0282   Stress: 736.140 MPa   max porosity: 0.19265    strain_increment: 0.00010    porosity increment: 0.00093
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 224
#   Strain: 0.0282   Stress: 735.575 MPa   max porosity: 0.19357    strain_increment: 0.00010    porosity increment: 0.00091
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 225
#   Strain: 0.0282   Stress: 735.017 MPa   max porosity: 0.19447    strain_increment: 0.00010    porosity increment: 0.00090
# Solution reached in 7 iterations.
# Number of broken points 1.0
# Increment 226
#   Strain: 0.0282   Stress: 734.467 MPa   max porosity: 0.19537    strain_increment: 0.00010    porosity increment: 0.00090
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 227
#   Strain: 0.0282   Stress: 733.924 MPa   max porosity: 0.19626    strain_increment: 0.00010    porosity increment: 0.00089
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 228
#   Strain: 0.0282   Stress: 733.388 MPa   max porosity: 0.19713    strain_increment: 0.00010    porosity increment: 0.00088
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 229
#   Strain: 0.0282   Stress: 732.859 MPa   max porosity: 0.19800    strain_increment: 0.00010    porosity increment: 0.00087
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 230
#   Strain: 0.0282   Stress: 732.336 MPa   max porosity: 0.19887    strain_increment: 0.00010    porosity increment: 0.00086
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 231
#   Strain: 0.0282   Stress: 731.819 MPa   max porosity: 0.19972    strain_increment: 0.00010    porosity increment: 0.00085
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 232
#   Strain: 0.0282   Stress: 731.307 MPa   max porosity: 0.20057    strain_increment: 0.00010    porosity increment: 0.00085
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 233
#   Strain: 0.0282   Stress: 730.801 MPa   max porosity: 0.20141    strain_increment: 0.00010    porosity increment: 0.00084
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 234
#   Strain: 0.0282   Stress: 730.300 MPa   max porosity: 0.20224    strain_increment: 0.00010    porosity increment: 0.00083
# Solution reached in 7 iterations.
# Number of broken points 1.0
# Increment 235
#   Strain: 0.0283   Stress: 729.803 MPa   max porosity: 0.20307    strain_increment: 0.00012    porosity increment: 0.00083
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 236
#   Strain: 0.0283   Stress: 729.226 MPa   max porosity: 0.20403    strain_increment: 0.00012    porosity increment: 0.00096
# Solution reached in 5 iterations.
# Number of broken points 1.0
# Increment 237
#   Strain: 0.0283   Stress: 728.567 MPa   max porosity: 0.20504    strain_increment: 0.00012    porosity increment: 0.00101
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 238
#   Strain: 0.0283   Stress: 727.888 MPa   max porosity: 0.20605    strain_increment: 0.00012    porosity increment: 0.00101
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 239
#   Strain: 0.0283   Stress: 727.218 MPa   max porosity: 0.20705    strain_increment: 0.00012    porosity increment: 0.00100
# Solution reached in 7 iterations.
# Number of broken points 1.0
# Increment 240
#   Strain: 0.0283   Stress: 726.557 MPa   max porosity: 0.20805    strain_increment: 0.00012    porosity increment: 0.00099
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 241
#   Strain: 0.0283   Stress: 725.905 MPa   max porosity: 0.20903    strain_increment: 0.00012    porosity increment: 0.00098
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 242
# ...
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 258
#   Strain: 0.0284   Stress: 715.264 MPa   max porosity: 0.22643    strain_increment: 0.00012    porosity increment: 0.00112
# Solution reached in 7 iterations.
# Number of broken points 1.0
# Increment 259
#   Strain: 0.0284   Stress: 714.619 MPa   max porosity: 0.22754    strain_increment: 0.00012    porosity increment: 0.00111
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 260
#   Strain: 0.0284   Stress: 713.982 MPa   max porosity: 0.22864    strain_increment: 0.00012    porosity increment: 0.00110
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 261
#   Strain: 0.0284   Stress: 713.350 MPa   max porosity: 0.22974    strain_increment: 0.00012    porosity increment: 0.00110
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 262
#   Strain: 0.0284   Stress: 712.725 MPa   max porosity: 0.23083    strain_increment: 0.00012    porosity increment: 0.00109
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 263
#   Strain: 0.0284   Stress: 712.105 MPa   max porosity: 0.23191    strain_increment: 0.00012    porosity increment: 0.00108
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 264
#   Strain: 0.0284   Stress: 711.491 MPa   max porosity: 0.23299    strain_increment: 0.00012    porosity increment: 0.00108
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 265
#   Strain: 0.0284   Stress: 710.882 MPa   max porosity: 0.23406    strain_increment: 0.00012    porosity increment: 0.00107
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 266
#   Strain: 0.0284   Stress: 710.279 MPa   max porosity: 0.23512    strain_increment: 0.00012    porosity increment: 0.00107
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 267
#   Strain: 0.0284   Stress: 709.680 MPa   max porosity: 0.23619    strain_increment: 0.00012    porosity increment: 0.00106
# Solution reached in 7 iterations.
# Number of broken points 1.0
# Increment 268
#   Strain: 0.0284   Stress: 709.085 MPa   max porosity: 0.23725    strain_increment: 0.00012    porosity increment: 0.00106
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 269
#   Strain: 0.0284   Stress: 708.495 MPa   max porosity: 0.23831    strain_increment: 0.00012    porosity increment: 0.00106
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 270
#   Strain: 0.0284   Stress: 707.909 MPa   max porosity: 0.23936    strain_increment: 0.00012    porosity increment: 0.00106
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 271
#   Strain: 0.0284   Stress: 707.268 MPa   max porosity: 0.24046    strain_increment: 0.00012    porosity increment: 0.00109
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 272
#   Strain: 0.0284   Stress: 706.582 MPa   max porosity: 0.24158    strain_increment: 0.00012    porosity increment: 0.00113
# Solution reached in 6 iterations.
# Number of broken points 1.0
# Increment 273
#   Strain: 0.0284   Stress: 705.902 MPa   max porosity: 0.24271    strain_increment: 0.00012    porosity increment: 0.00113
# Solution reached in 7 iterations.
# Number of broken points 1.0
# Increment 274
#   Strain: 0.0284   Stress: 705.226 MPa   max porosity: 0.24386    strain_increment: 0.00012    porosity increment: 0.00114
# Solution reached in 7 iterations.
# Number of broken points 1.0
# Increment 275
#   Strain: 0.0285   Stress: 704.555 MPa   max porosity: 0.24502    strain_increment: 0.00012    porosity increment: 0.00116
# Solution reached in 6 iterations.
# Number of broken points 2.0
# Increment 276
#   Strain: 0.0285   Stress: 703.819 MPa   max porosity: 0.23985    strain_increment: 0.00010    porosity increment: 0.00517
# Solution reached in 7 iterations.
# Number of broken points 2.0
# Increment 277
#   Strain: 0.0285   Stress: 703.273 MPa   max porosity: 0.24033    strain_increment: 0.00015    porosity increment: 0.00048
# Solution reached in 6 iterations.
# Number of broken points 2.0
# Increment 278
#   Strain: 0.0285   Stress: 702.441 MPa   max porosity: 0.24224    strain_increment: 0.00010    porosity increment: 0.00191
# Solution reached in 8 iterations.
# Number of broken points 2.0
# Increment 279
#   Strain: 0.0285   Stress: 701.891 MPa   max porosity: 0.24428    strain_increment: 0.00010    porosity increment: 0.00205
# Solution reached in 6 iterations.
# Number of broken points 3.0
# Increment 280
#   Strain: 0.0285   Stress: 701.105 MPa   max porosity: 0.24213    strain_increment: 0.00010    porosity increment: 0.00215
# Solution reached in 7 iterations.
# Number of broken points 3.0
# Increment 281
#   Strain: 0.0285   Stress: 700.700 MPa   max porosity: 0.24256    strain_increment: 0.00016    porosity increment: 0.00043
# Solution reached in 7 iterations.
# Number of broken points 3.0
# Increment 282
#   Strain: 0.0285   Stress: 700.062 MPa   max porosity: 0.24323    strain_increment: 0.00021    porosity increment: 0.00067
# Solution reached in 7 iterations.
# Number of broken points 3.0
# Increment 283
#   Strain: 0.0285   Stress: 699.218 MPa   max porosity: 0.24413    strain_increment: 0.00021    porosity increment: 0.00089
# Solution reached in 7 iterations.
# Number of broken points 3.0
# Increment 284
#   Strain: 0.0285   Stress: 698.379 MPa   max porosity: 0.24502    strain_increment: 0.00021    porosity increment: 0.00089
# Solution reached in 7 iterations.
# Number of broken points 3.0
# Increment 285
#   Strain: 0.0285   Stress: 697.543 MPa   max porosity: 0.24591    strain_increment: 0.00021    porosity increment: 0.00089
# Solution reached in 7 iterations.
# Number of broken points 4.0
# Increment 286
#   Strain: 0.0285   Stress: 696.681 MPa   max porosity: 0.24244    strain_increment: 0.00010    porosity increment: 0.00348
# Solution reached in 5 iterations.
# Number of broken points 4.0
# Increment 287
#   Strain: 0.0285   Stress: 696.288 MPa   max porosity: 0.24294    strain_increment: 0.00015    porosity increment: 0.00050
# Solution reached in 6 iterations.
# Number of broken points 4.0
# Increment 288
#   Strain: 0.0285   Stress: 695.685 MPa   max porosity: 0.24370    strain_increment: 0.00019    porosity increment: 0.00076
# Solution reached in 5 iterations.
# Number of broken points 4.0
# Increment 289
#   Strain: 0.0285   Stress: 694.818 MPa   max porosity: 0.24468    strain_increment: 0.00019    porosity increment: 0.00098
# Solution reached in 5 iterations.
# Number of broken points 4.0
# Increment 290
#   Strain: 0.0286   Stress: 693.956 MPa   max porosity: 0.24566    strain_increment: 0.00019    porosity increment: 0.00098
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 291
#   Strain: 0.0286   Stress: 693.010 MPa   max porosity: 0.21531    strain_increment: 0.00010    porosity increment: 0.03035
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 292
#   Strain: 0.0286   Stress: 692.567 MPa   max porosity: 0.21566    strain_increment: 0.00016    porosity increment: 0.00036
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 293
#   Strain: 0.0286   Stress: 691.842 MPa   max porosity: 0.21625    strain_increment: 0.00023    porosity increment: 0.00059
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 294
#   Strain: 0.0286   Stress: 690.821 MPa   max porosity: 0.21708    strain_increment: 0.00027    porosity increment: 0.00083
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 295
#   Strain: 0.0286   Stress: 689.635 MPa   max porosity: 0.21804    strain_increment: 0.00027    porosity increment: 0.00097
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 296
#   Strain: 0.0286   Stress: 688.462 MPa   max porosity: 0.21901    strain_increment: 0.00027    porosity increment: 0.00096
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 297
#   Strain: 0.0286   Stress: 687.302 MPa   max porosity: 0.21997    strain_increment: 0.00027    porosity increment: 0.00096
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 298
#   Strain: 0.0286   Stress: 686.154 MPa   max porosity: 0.22093    strain_increment: 0.00027    porosity increment: 0.00096
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 299
#   Strain: 0.0286   Stress: 685.016 MPa   max porosity: 0.22188    strain_increment: 0.00027    porosity increment: 0.00095
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 300
#   Strain: 0.0287   Stress: 683.889 MPa   max porosity: 0.22283    strain_increment: 0.00027    porosity increment: 0.00095
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 301
#   Strain: 0.0287   Stress: 682.724 MPa   max porosity: 0.22379    strain_increment: 0.00027    porosity increment: 0.00096
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 302
#   Strain: 0.0287   Stress: 681.422 MPa   max porosity: 0.22478    strain_increment: 0.00027    porosity increment: 0.00099
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 303
#   Strain: 0.0287   Stress: 680.133 MPa   max porosity: 0.22576    strain_increment: 0.00027    porosity increment: 0.00098
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 304
#   Strain: 0.0287   Stress: 678.858 MPa   max porosity: 0.22674    strain_increment: 0.00027    porosity increment: 0.00098
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 305
#   Strain: 0.0287   Stress: 677.597 MPa   max porosity: 0.22772    strain_increment: 0.00027    porosity increment: 0.00098
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 306
#   Strain: 0.0287   Stress: 676.352 MPa   max porosity: 0.22870    strain_increment: 0.00027    porosity increment: 0.00097
# Solution reached in 7 iterations.
# Number of broken points 5.0
# Increment 307
#   Strain: 0.0287   Stress: 675.122 MPa   max porosity: 0.22967    strain_increment: 0.00027    porosity increment: 0.00097
# Solution reached in 7 iterations.
# Number of broken points 5.0
# Increment 308
#   Strain: 0.0287   Stress: 673.907 MPa   max porosity: 0.23064    strain_increment: 0.00027    porosity increment: 0.00097
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 309
#   Strain: 0.0288   Stress: 672.706 MPa   max porosity: 0.23160    strain_increment: 0.00027    porosity increment: 0.00097
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 310
#   Strain: 0.0288   Stress: 671.519 MPa   max porosity: 0.23260    strain_increment: 0.00027    porosity increment: 0.00100
# Solution reached in 7 iterations.
# Number of broken points 5.0
# Increment 311
#   Strain: 0.0288   Stress: 670.345 MPa   max porosity: 0.23432    strain_increment: 0.00010    porosity increment: 0.00172
# Solution reached in 5 iterations.
# Number of broken points 5.0
# Increment 312
#   Strain: 0.0288   Stress: 669.919 MPa   max porosity: 0.23495    strain_increment: 0.00014    porosity increment: 0.00063
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 313
#   Strain: 0.0288   Stress: 669.336 MPa   max porosity: 0.23581    strain_increment: 0.00014    porosity increment: 0.00086
# Solution reached in 5 iterations.
# Number of broken points 5.0
# Increment 314
#   Strain: 0.0288   Stress: 668.757 MPa   max porosity: 0.23667    strain_increment: 0.00014    porosity increment: 0.00086
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 315
#   Strain: 0.0288   Stress: 668.181 MPa   max porosity: 0.23753    strain_increment: 0.00014    porosity increment: 0.00086
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 316
#   Strain: 0.0288   Stress: 667.563 MPa   max porosity: 0.23840    strain_increment: 0.00014    porosity increment: 0.00088
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 317
#   Strain: 0.0288   Stress: 666.904 MPa   max porosity: 0.23929    strain_increment: 0.00014    porosity increment: 0.00089
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 318
#   Strain: 0.0288   Stress: 666.248 MPa   max porosity: 0.24019    strain_increment: 0.00014    porosity increment: 0.00089
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 319
#   Strain: 0.0288   Stress: 665.596 MPa   max porosity: 0.24108    strain_increment: 0.00014    porosity increment: 0.00089
# Solution reached in 5 iterations.
# Number of broken points 5.0
# Increment 320
#   Strain: 0.0288   Stress: 664.948 MPa   max porosity: 0.24197    strain_increment: 0.00014    porosity increment: 0.00089
# Solution reached in 5 iterations.
# Number of broken points 5.0
# Increment 321
#   Strain: 0.0288   Stress: 664.303 MPa   max porosity: 0.24286    strain_increment: 0.00014    porosity increment: 0.00089
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 322
#   Strain: 0.0288   Stress: 663.661 MPa   max porosity: 0.24375    strain_increment: 0.00014    porosity increment: 0.00089
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 323
#   Strain: 0.0289   Stress: 663.024 MPa   max porosity: 0.24464    strain_increment: 0.00014    porosity increment: 0.00089
# Solution reached in 6 iterations.
# Number of broken points 5.0
# Increment 324
#   Strain: 0.0289   Stress: 662.390 MPa   max porosity: 0.24553    strain_increment: 0.00014    porosity increment: 0.00089
# Solution reached in 5 iterations.
# Number of broken points 6.0
# Increment 325
#   Strain: 0.0289   Stress: 661.639 MPa   max porosity: 0.24027    strain_increment: 0.00010    porosity increment: 0.00525
# Solution reached in 5 iterations.
# Number of broken points 6.0
# Increment 326
#   Strain: 0.0289   Stress: 661.208 MPa   max porosity: 0.24062    strain_increment: 0.00017    porosity increment: 0.00035
# Solution reached in 6 iterations.
# Number of broken points 6.0
# Increment 327
#   Strain: 0.0289   Stress: 660.498 MPa   max porosity: 0.24120    strain_increment: 0.00024    porosity increment: 0.00058
# Solution reached in 6 iterations.
# Number of broken points 6.0
# Increment 328
#   Strain: 0.0289   Stress: 659.493 MPa   max porosity: 0.24202    strain_increment: 0.00028    porosity increment: 0.00082
# Solution reached in 5 iterations.
# Number of broken points 6.0
# Increment 329
#   Strain: 0.0289   Stress: 658.316 MPa   max porosity: 0.24298    strain_increment: 0.00028    porosity increment: 0.00096
# Solution reached in 6 iterations.
# Number of broken points 6.0
# Increment 330
#   Strain: 0.0289   Stress: 657.152 MPa   max porosity: 0.24394    strain_increment: 0.00028    porosity increment: 0.00096
# Solution reached in 5 iterations.
# Number of broken points 6.0
# Increment 331
#   Strain: 0.0289   Stress: 655.999 MPa   max porosity: 0.24490    strain_increment: 0.00028    porosity increment: 0.00096
# Solution reached in 6 iterations.
# Number of broken points 7.0
# Increment 332
#   Strain: 0.0289   Stress: 654.732 MPa   max porosity: 0.24588    strain_increment: 0.00028    porosity increment: 0.00098
# Solution reached in 5 iterations.
# Number of broken points 8.0
# Increment 333
#   Strain: 0.0289   Stress: 653.661 MPa   max porosity: 0.24575    strain_increment: 0.00052    porosity increment: 0.00013
# Solution reached in 5 iterations.
# Number of broken points 9.0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[21], line 135
#     133 rewrite = (i==1)
#     134 save_to_file(out_file, u, t=U, rewrite=rewrite)
# --> 135 save_to_file(out_file, porosity, t=U, rewrite=rewrite)
#     136 save_to_file(out_file, p, t=U, rewrite=rewrite)
#     138 # Evaluate fields at given points
#
# File ~/.local/lib/python3.10/site-packages/mealor/utils.py:125, in save_to_file(filename, u, t, rewrite)
#     123         xdmf.write_function(u, t)
#     124 else:
# --> 125     with io.XDMFFile(domain.comm, filename, "a") as xdmf:
#     126         xdmf.write_function(u, t)
#
# RuntimeError: Failed to create/open HDF5 file (append mode).
